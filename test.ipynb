# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaytech002/DataScience_Python/blob/master/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy.distutils.system_info as sysinfo

# %%
sysinfo.platform_bits
# Out:
# 64

# %% [markdown]
# # New Section
